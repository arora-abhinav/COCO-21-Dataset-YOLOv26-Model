# %%
from ultralytics import YOLO

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())
# Out:
# True
# NVIDIA GeForce RTX 2060 SUPER

# %%
model = YOLO("yolo26l-pose.pt") 

results = model.train(
    data="custom_coco.yaml",
    epochs=50,
    imgsz=640,
    batch=2,          # Safe physical batch size for 2060 RTX
    optimizer="MuSGD",
    device=0,
    workers=0,
    cache="disk"
)

model.save("coco21.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26l-pose.pt to 'yolo26l-pose.pt': 100% ━━━━━━━━━━━━ 55.3MB 11.1MB/s 5.0s5.0s<0.0s9s
# Ultralytics 8.4.87  Python-3.12.1 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2060 SUPER, 8192MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=custom_coco.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26l-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-6, nbs=64, nms=False, opset=None, optimize=False, optimizer=MuSGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Abhinav Arora\Desktop\COCO custom model\runs\pose\train-6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[21, 3]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   5937792  ultralytics.nn.modules.head.Pose26           [1, [21, 3], 1, True, [256, 512, 512]]
# YOLO26l-pose summary: 495 layers, 29,315,520 parameters, 29,315,520 gradients, 106.8 GFLOPs
#
# Transferred 1179/1263 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.1 ms, read: 217.184.0 MB/s, size: 164.3 KB)
# train: Scanning C:\Users\Abhinav Arora\Desktop\COCO custom model\dataset\labels\train.cache... 29730 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 29730/29730  0.0s
# train: Caching images (22.9GB Disk): 100% ━━━━━━━━━━━━ 29730/29730 14.3Kit/s 2.1s0.1s
# val: Fast image access  (ping: 0.10.0 ms, read: 555.1391.4 MB/s, size: 158.7 KB)
# val: Scanning C:\Users\Abhinav Arora\Desktop\COCO custom model\dataset\labels\val.cache... 995 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 995/995  0.0s
# val: Caching images (0.8GB Disk): 100% ━━━━━━━━━━━━ 995/995 22.4Kit/s 0.0s
# optimizer: MuSGD(lr=0.01, momentum=0.937) with parameter groups 190 weight(decay=0.0), 250 weight(decay=0.0005), 250 bias(decay=0.0)
# Plotting labels to C:\Users\Abhinav Arora\Desktop\COCO custom model\runs\pose\train-6\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\Abhinav Arora\Desktop\COCO custom model\runs\pose\train-6
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss   rle_loss  Instances       Size
#       1/100      9.16G      1.281      6.579     0.7087      1.527   0.008192      17.57         19        640: 0% ──────────── 73/7433 3.3s/it 3:58<6:41:221
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 model = YOLO("yolo26l-pose.pt")
#       2
# ----> 3 results = model.train(
#       4     data="custom_coco.yaml",
#       5     epochs=100,
#       6     imgsz=640,
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\ultralytics\engine\model.py:814, in Model.train(self, trainer, **kwargs)
#     811     self.trainer.model = self.trainer.get_model(weights=weights, cfg=self.model.yaml)
#     812     self.model = self.trainer.model
# --> 814 self.trainer.train()
#     815 # Update model and cfg after training
#     816 if RANK in {-1, 0}:
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\ultralytics\engine\trainer.py:241, in BaseTrainer.train(self)
#     238             ddp_cleanup(self, str(file))
#     240 else:
# --> 241     self._do_train()
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\ultralytics\engine\trainer.py:495, in BaseTrainer._do_train(self)
#     493     break  # restart epoch loop with reduced batch size
#     494 if ni - last_opt_step >= self.accumulate:
# --> 495     self.optimizer_step()
#     496     last_opt_step = ni
#     498     # Timed stopping
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\ultralytics\engine\trainer.py:788, in BaseTrainer.optimizer_step(self)
#     786 self.scaler.unscale_(self.optimizer)  # unscale gradients
#     787 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)
# --> 788 self.scaler.step(self.optimizer)
#     789 self.scaler.update()
#     790 self.optimizer.zero_grad()
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\torch\amp\grad_scaler.py:457, in GradScaler.step(self, optimizer, *args, **kwargs)
#     451     self.unscale_(optimizer)
#     453 assert (
#     454     len(optimizer_state["found_inf_per_device"]) > 0
#     455 ), "No inf checks were recorded for this optimizer."
# --> 457 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     459 optimizer_state["stage"] = OptState.STEPPED
#     461 return retval
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\torch\amp\grad_scaler.py:352, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     350 retval: Optional[float] = None
#     351 if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# --> 352     retval = optimizer.step(*args, **kwargs)
#     353 return retval
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\torch\optim\lr_scheduler.py:140, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     138 opt = opt_ref()
#     139 opt._opt_called = True  # type: ignore[union-attr]
# --> 140 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\torch\optim\optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\ultralytics\optim\muon.py:218, in MuSGD.step(self, closure)
#     215     state["momentum_buffer"] = torch.zeros_like(p)
#     216     state["momentum_buffer_SGD"] = torch.zeros_like(p)
# --> 218 update = muon_update(
#     219     grad, state["momentum_buffer"], beta=group["momentum"], nesterov=group["nesterov"]
#     220 )
#     221 p.add_(update.reshape(p.shape), alpha=-(lr * self.muon))
#     223 # SGD update
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\ultralytics\optim\muon.py:94, in muon_update(grad, momentum, beta, nesterov)
#      92 if update.ndim == 4:  # for the case of conv filters
#      93     update = update.view(len(update), -1)
# ---> 94 update = zeropower_via_newtonschulz5(update)
#      95 update *= max(1, grad.size(-2) / grad.size(-1)) ** 0.5
#      96 return update
#
# File c:\Users\Abhinav Arora\Desktop\COCO custom model\.venv\Lib\site-packages\ultralytics\optim\muon.py:53, in zeropower_via_newtonschulz5(G, eps)
#      51     A = X @ X.T
#      52     B = b * A + c * A @ A
# ---> 53     X = a * X + B @ X
#      54 if G.size(0) > G.size(1):
#      55     X = X.T
#
# KeyboardInterrupt:
